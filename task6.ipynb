# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../TH_Data/100_rows.csv')
df['minmax_norm'] = 1 + (df['4'] - df['4'].min()) / (df['4'].max() - df['4'].min()) * 9
df['mean_norm'] = 1 + (df['4'] - df['4'].mean()) / (df['4'].max() - df['4'].min()) * 9
df.head()
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  https://www.goodreads.com//book/show/40605251-...
# 1           1  https://www.goodreads.com//book/show/21787.The...
# 2           2  https://www.goodreads.com//book/show/13812.Mag...
# 3           3  https://www.goodreads.com//book/show/40605251-...
# 4           4  https://www.goodreads.com//book/show/21787.The...
#
#                                                    1                   2  \
# 0                                  A Game of Thrones  George R.R. Martin
# 1  J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...      J.R.R. Tolkien
# 2                               The Name of the Wind    Patrick Rothfuss
# 3                                   The Way of Kings   Brandon Sanderson
# 4                           The Chronicles of Narnia          C.S. Lewis
#
#                 3     4     5     6                                 7  \
# ...

# %%
fig, graph = plt.subplots(figsize = (15, 8))

graph.hist(df.minmax_norm, bins = 30, alpha = 0.7, color = 'blue', edgecolor = 'white', label = 'Min-Max normalization')
graph.hist(df.mean_norm, bins = 30, alpha = 0.7, color='orange', edgecolor = 'white', label = 'Mean normalization')
graph.set_title('Comparison between Min-Max normalization and Mean normalization')
graph.legend()
graph.set_xlabel('Ratings (normalized 1 - 10)')
# Out:
# Text(0.5, 0, 'Ratings (normalized 1 - 10)')
