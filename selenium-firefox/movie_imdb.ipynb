# %%
# Import the needed libraries
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import seaborn as sns

from selenium.webdriver.common.by  import By as selenium_By
from selenium.webdriver.support.ui import Select as selenium_Select
from selenium.webdriver.support.ui import WebDriverWait as selenium_WebDriverWait
from selenium.webdriver.support    import expected_conditions as selenium_ec
from selenium.webdriver.firefox.options import Options as selenium_options
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities as selenium_DesiredCapabilities
from selenium import webdriver as selenium_webdriver
import time
from datetime import datetime

# %%
browser = webdriver.Firefox(executable_path="./drivers/geckodriver")  ## Firefox

# %%
browser.get('https://www.imdb.com/search/title/?title_type=feature&num_votes=25000,&genres=horror&sort=user_rating,desc&view=advanced')
print('Title: %s' % browser.title)
# Out:
# Title: Feature Film, Rating Count at least 25,000, Horror (Sorted by IMDb Rating Descending) - IMDb

# %%
element1 = browser.find_element_by_class_name("lister-list")

# %%
print(element1.text)
# Out:
# 1. Psycho (1960)
# R | 109 min | Horror, Mystery, Thriller
# 8.5 Rate this
# 97 Metascore
# A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run, and checks into a remote motel run by a young man under the domination of his mother.
# Director: Alfred Hitchcock | Stars: Anthony Perkins, Janet Leigh, Vera Miles, John Gavin
# Votes: 610,136 | Gross: $32.00M
# 2. The Shining (1980)
# R | 146 min | Drama, Horror
# 8.4 Rate this
# 66 Metascore
# A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence, while his psychic son sees horrific forebodings from both past and future.
# Director: Stanley Kubrick | Stars: Jack Nicholson, Shelley Duvall, Danny Lloyd, Scatman Crothers
# Votes: 907,990 | Gross: $44.02M
# 3. Alien (1979)
# R | 117 min | Horror, Sci-Fi
# 8.4 Rate this
# 89 Metascore
# ...

# %%
element2 = element1.text
print(len(element2))
print(type(element2))
#element3 = element2[0:(5000-248)]
# Out:
# 17638
# <class 'str'>

# %%
#for sharing to others
text_file = open("string_file.txt", "w")
text_file.write(element2)
text_file.close()

# %%
print(len(element2))
print(type(element2))
# one row is equal to 7 \n
print(element2.count("\n"))
#len(new_txt_list)
#element2
# Out:
# 17638
# <class 'str'>
# 342

# %%
import re 
element3 =re.sub('\n[0-9][0-9] Metascore','', element2)
print(element3)
# Out:
# 1. Psycho (1960)
# R | 109 min | Horror, Mystery, Thriller
# 8.5 Rate this
# A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run, and checks into a remote motel run by a young man under the domination of his mother.
# Director: Alfred Hitchcock | Stars: Anthony Perkins, Janet Leigh, Vera Miles, John Gavin
# Votes: 610,136 | Gross: $32.00M
# 2. The Shining (1980)
# R | 146 min | Drama, Horror
# 8.4 Rate this
# A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence, while his psychic son sees horrific forebodings from both past and future.
# Director: Stanley Kubrick | Stars: Jack Nicholson, Shelley Duvall, Danny Lloyd, Scatman Crothers
# Votes: 907,990 | Gross: $44.02M
# 3. Alien (1979)
# R | 117 min | Horror, Sci-Fi
# 8.4 Rate this
# ...

# %%
# one tag is equal to 7 \n
new_txt_list = element3.split('\n')
"""
[....................]
[[],[],[],[],[],[]]
[[],[],[],[],[],[]]
[[],[],[],[],[],[]]
[[],[],[],[],[],[]]]
"""

new_txt_list[] -> new_txt_list[0]
# Out:
# 'R | 109 min | Horror, Mystery, Thriller'

# %%
new_txt_list = element3.split('\n')
new_dict = {}
sublist = [new_txt_list[i: i + 7] for i in range(0, len(new_txt_list), 6)]
mydf = pd.DataFrame(sublist)
mydf
# Out:
#                                                     0  \
# 0                                    1. Psycho (1960)
# 1                               2. The Shining (1980)
# 2                                     3. Alien (1979)
# 3                                   4. Tumbbad (2018)
# 4                         5. The Blue Elephant (2014)
# 5                                 6. The Thing (1982)
# 6          7. What Ever Happened to Baby Jane? (1962)
# 7               8. The Cabinet of Dr. Caligari (1920)
# 8                              9. The Exorcist (1973)
# 9                          10. Rosemary's Baby (1968)
# 10                              11. Diabolique (1955)
# 11                    12. Let the Right One In (2008)
# 12                       13. Shaun of the Dead (2004)
# 13                        14. Dawn of the Dead (1978)
# 14                15. Night of the Living Dead (1968)
# 15                               16. King Kong (1933)
# ...

# %%
mydf.columns=["row1", "row2","row3", "row4","row5", "row6", "row7"]
mydf

mydf[['rating','min','genre']] = mydf.row2.str.split("|",expand=True,)
#mydf

# %%
mydf.head()
mydf[['Director','Stars']] = mydf.row5.str.split("|",expand=True,)
mydf[['Votes','Gross']] = mydf.row6.str.split("|",expand=True,)

# %%
#mydf.pop('row5')# df.drop(['B', 'C'], axis=1)
mydf.pop('row6')# df.drop(['B', 'C'], axis=1)
mydf.pop('row2')# df.drop(['B', 'C'], axis=1)
mydf
# Out:
#                                                  row1           row3  \
# 0                                    1. Psycho (1960)  8.5 Rate this
# 1                               2. The Shining (1980)  8.4 Rate this
# 2                                     3. Alien (1979)  8.4 Rate this
# 3                                   4. Tumbbad (2018)  8.3 Rate this
# 4                         5. The Blue Elephant (2014)  8.1 Rate this
# 5                                 6. The Thing (1982)  8.1 Rate this
# 6          7. What Ever Happened to Baby Jane? (1962)  8.1 Rate this
# 7               8. The Cabinet of Dr. Caligari (1920)  8.1 Rate this
# 8                              9. The Exorcist (1973)  8.0 Rate this
# 9                          10. Rosemary's Baby (1968)  8.0 Rate this
# 10                              11. Diabolique (1955)  8.0 Rate this
# 11                    12. Let the Right One In (2008)  7.9 Rate this
# 12                       13. Shaun of the Dead (2004)  7.9 Rate this
# ...

# %%
mydf[['movie_name','year']] = mydf.row1.str.split("(",expand=True,)
mydf.pop('row7')
mydf.columns=["MovieName", "Rating","Description", "Rated","Duration", "Genre", "Director","Stars","votes","Gross"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-2e9c0c053926> in <module>
# ----> 1 mydf[['movie_name','year']] = mydf.row1.str.split("(",expand=True,)
#       2 mydf.pop('row7')
#       3 mydf.columns=["MovieName", "Rating","Description", "Rated","Duration", "Genre", "Director","Stars","votes","Gross"]
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3158             self._setitem_frame(key, value)
#    3159         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3160             self._setitem_array(key, value)
#    3161         else:
#    3162             # set column
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3187             if isinstance(value, DataFrame):
# ...

# %%
mydf
#mydf['Rating/votes'] = mydf['Rating']/mydf['votes']
# Out:
#                                             MovieName         Rating  \
# 0                                    1. Psycho (1960)  8.5 Rate this
# 1                               2. The Shining (1980)  8.4 Rate this
# 2                                     3. Alien (1979)  8.4 Rate this
# 3                                   4. Tumbbad (2018)  8.3 Rate this
# 4                         5. The Blue Elephant (2014)  8.1 Rate this
# 5                                 6. The Thing (1982)  8.1 Rate this
# 6          7. What Ever Happened to Baby Jane? (1962)  8.1 Rate this
# 7               8. The Cabinet of Dr. Caligari (1920)  8.1 Rate this
# 8                              9. The Exorcist (1973)  8.0 Rate this
# 9                          10. Rosemary's Baby (1968)  8.0 Rate this
# 10                              11. Diabolique (1955)  8.0 Rate this
# 11                    12. Let the Right One In (2008)  7.9 Rate this
# 12                       13. Shaun of the Dead (2004)  7.9 Rate this
# ...

# %%
browser.quit()
